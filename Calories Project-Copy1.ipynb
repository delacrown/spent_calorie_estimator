# %%
import pandas as pd

calories = pd.read_csv("C:\\Users\\Rotimi\\Downloads\\archive (3)\\calories.csv")
exercise = pd.read_csv("C:\\Users\\Rotimi\\Downloads\\archive (3)\\exercise.csv")

# %%
calories
# Out:
#         User_ID  Calories
# 0      14733363     231.0
# 1      14861698      66.0
# 2      11179863      26.0
# 3      16180408      71.0
# 4      17771927      35.0
# ...         ...       ...
# 14995  15644082      45.0
# 14996  17212577      23.0
# 14997  17271188      75.0
# 14998  18643037      11.0
# 14999  11751526      98.0
#
# [15000 rows x 2 columns]

# %%
exercise
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
# [15000 rows x 8 columns]

# %%
data = calories.merge(exercise, on = 'User_ID')
data
# Out:
#         User_ID  Calories  Gender  Age  Height  Weight  Duration  Heart_Rate  \
# 0      14733363     231.0    male   68   190.0    94.0      29.0       105.0
# 1      14861698      66.0  female   20   166.0    60.0      14.0        94.0
# 2      11179863      26.0    male   69   179.0    79.0       5.0        88.0
# 3      16180408      71.0  female   34   179.0    71.0      13.0       100.0
# 4      17771927      35.0  female   27   154.0    58.0      10.0        81.0
# ...         ...       ...     ...  ...     ...     ...       ...         ...
# 14995  15644082      45.0  female   20   193.0    86.0      11.0        92.0
# 14996  17212577      23.0  female   27   165.0    65.0       6.0        85.0
# 14997  17271188      75.0  female   43   159.0    58.0      16.0        90.0
# 14998  18643037      11.0    male   78   193.0    97.0       2.0        84.0
# 14999  11751526      98.0    male   63   173.0    79.0      18.0        92.0
#
#        Body_Temp
# 0           40.8
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Calories    15000 non-null  float64
#  2   Gender      15000 non-null  object
#  3   Age         15000 non-null  int64
#  4   Height      15000 non-null  float64
#  5   Weight      15000 non-null  float64
#  6   Duration    15000 non-null  float64
#  7   Heart_Rate  15000 non-null  float64
#  8   Body_Temp   15000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.0+ MB

# %%
data.describe()
# Out:
#             User_ID      Calories           Age        Height        Weight  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     89.539533     42.789800    174.465133     74.966867
# std    2.872851e+06     62.456978     16.980264     14.258114     15.035657
# min    1.000116e+07      1.000000     20.000000    123.000000     36.000000
# 25%    1.247419e+07     35.000000     28.000000    164.000000     63.000000
# 50%    1.499728e+07     79.000000     39.000000    175.000000     74.000000
# 75%    1.744928e+07    138.000000     56.000000    185.000000     87.000000
# max    1.999965e+07    314.000000     79.000000    222.000000    132.000000
#
#            Duration    Heart_Rate     Body_Temp
# count  15000.000000  15000.000000  15000.000000
# mean      15.530600     95.518533     40.025453
# std        8.319203      9.583328      0.779230
# min        1.000000     67.000000     37.100000
# ...

# %%
sum(data.duplicated())
# Out:
# 0

# %%
data.drop('User_ID', axis = 1, inplace = True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
gender_counts = data['Gender'].value_counts()

plt.bar(gender_counts.index, gender_counts)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Counts')

plt.show()

# %%
sns.histplot(data['Age']) 
plt.title('Age Distribution')
plt.xlabel('Ages')
plt.ylabel('Frequency') 
plt.show()
# Out:
# C:\Users\Rotimi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data['Calories']) 
plt.title('Calories Distribution')
plt.xlabel('Calories')
plt.ylabel('Frequency') 
plt.show()
# Out:
# C:\Users\Rotimi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data['Height']) 
plt.title('Height Distribution')
plt.xlabel('Height')
plt.ylabel('Frequency') 
plt.show()
# Out:
# C:\Users\Rotimi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data['Weight'])
plt.title('Weight Distribution')
plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\Rotimi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data['Duration'])
plt.ylabel('Frequency')
plt.xlabel('Duration')
plt.title('Duration')
plt.show()
# Out:
# C:\Users\Rotimi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data['Heart_Rate'])
plt.title('Heart Rate Distribution')
plt.xlabel('Heart_Rate')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\Rotimi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data['Body_Temp'])
plt.title('Body Temperature Distribution')
plt.xlabel('Body_Temp')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\Rotimi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
b_plot = data[['Calories', 'Age', 'Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp']]

plt.figure(figsize = (10, 6))
sns.boxplot(data = b_plot)

plt.title('Box plot of Variables')

plt.show()

# %%
df = data.copy()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

data['Gender'] = le.fit_transform(data['Gender'])

# %%
corr_matrix = data.corr()
print(corr_matrix)
# Out:
#             Calories    Gender       Age    Height    Weight  Duration  \
# Calories    1.000000  0.022357  0.154395  0.017537  0.035481  0.955421
# Gender      0.022357  1.000000  0.003222  0.710534  0.783186  0.003440
# Age         0.154395  0.003222  1.000000  0.009554  0.090094  0.013247
# Height      0.017537  0.710534  0.009554  1.000000  0.958451 -0.004625
# Weight      0.035481  0.783186  0.090094  0.958451  1.000000 -0.001884
# Duration    0.955421  0.003440  0.013247 -0.004625 -0.001884  1.000000
# Heart_Rate  0.897882  0.011555  0.010482  0.000528  0.004311  0.852869
# Body_Temp   0.824558  0.007264  0.013175  0.001200  0.004095  0.903167
#
#             Heart_Rate  Body_Temp
# Calories      0.897882   0.824558
# Gender        0.011555   0.007264
# Age           0.010482   0.013175
# Height        0.000528   0.001200
# Weight        0.004311   0.004095
# Duration      0.852869   0.903167
# Heart_Rate    1.000000   0.771529
# Body_Temp     0.771529   1.000000

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error,r2_score
from sklearn import metrics
import numpy as np

# %%
x = data.drop('Calories', axis = 1)
y = data['Calories'].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
ln_reg = LinearRegression()

# %%
ln_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = ln_reg.predict(x_test)

# %%
print('r2: ', metrics.r2_score(y_test, y_pred))
# Out:
# r2:  0.9672937151257295

# %%
import pickle 
pickle.dump(ln_reg, open("C:\\Users\\Rotimi\\Downloads\\ln_regproject.pkl", 'wb'))

# %%
data['Gender'].unique()
# Out:
# array([1, 0])

# %%
le.fit(df['Gender'])
gender = le.inverse_transform(data['Gender'])

gender
df1 = pd.DataFrame(gender)
df1[0].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data.columns
# Out:
# Index(['Calories', 'Gender', 'Age', 'Height', 'Weight', 'Duration',
#        'Heart_Rate', 'Body_Temp'],
#       dtype='object')
